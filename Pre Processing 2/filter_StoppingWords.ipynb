# %% [markdown]
# Filter the Stopping Words

# %% [markdown]
# ### Read Data

# %%
import os

print("Current Working Directory:", os.getcwd())
files=["../data/anchorwm.txt","../data/honda.txt"]
file_contents=[]
for x in files:
    with open(x,'r') as file:
        content = file.read()
        file_contents.append(content)
print(file_contents)
# Out:
# Current Working Directory: d:\GT-Document-Classification\Pre Processing 2
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# ["          Anchor Wealth Management - Financial Advisors In Rockford, IL                                                                                      Skip to content                                 HomeAboutServices Services Financial Planning Investment Planning Long-Term Care & Life InsuranceCaptain’s LogAnchor in the NewsRefer A FriendLoginContact Us          815-201-5011                             HomeAboutServices Services Financial Planning Investment Planning Long-Term Care & Life InsuranceCaptain’s LogAnchor in the NewsRefer A FriendLoginContact Us                                                  CHART YOUR FINANCIAL COURSE TODAY             Begin Your Journey      Contact Form  Do not fill this form out if you're a solicitor.Name*   First    Last  Phone*Email*  Street Address PO Box or Apt # City* StateAlabamaAlaskaArizonaArkansasCaliforniaColoradoConnecticutDelawareFloridaGeorgiaGuamHawaiiIdahoIllinoisIndianaIowaKansasKentuckyLouisianaMaineMarylandMassachusettsMichiganMinnesotaMississippiMissouriMontanaNebraskaNevadaNew HampshireNew JerseyNew MexicoNew YorkNorth CarolinaNorth DakotaOhioOklahomaOregonPennsylvaniaRhode IslandSouth CarolinaSouth DakotaTennesseeTexasUtahVermontVirginiaWashingtonWest VirginiaWisconsinWyomingZip Code* What brought you to Anchor Wealth?  Financial Planning   Investments   Life Insurance   Long-Term Care Insurance My current investments(Select all that apply)  Roth IRA   401k/403b   Deferred Comp   College ESA/529   Annuities   Pension   Mutual Funds   Stocks/Bonds   CDs My current debts(Select all that apply)  Credit cards   School loans   Mortgage   Bank loans   Car loans   Personal loans   I'm debt free!!! How did you hear about us?  Radio Advertisement   Digital Advertisement   Internet search   Friend/family referral   Dave Ramsey Anything else you would like us to know or discuss?CAPTCHAPhoneThis field is for validation purposes and should be left unchanged.                                                            Check The Background\xa0Of This Investment Professional On FINRA’s BrokerCheck           OUR PROCESS                  Learn                      Teach                      Begin                      Stay                                 HOW WE WORK        As with any long journey, we begin wealth management planning with the end in mind. By understanding where you want to be when the journey ends, we are better able to chart the course as your financial advisors. And while we can never predict all of the bumps and diversions, we can better prepare for them. Get in contact with a financial advisor in Rockford, Freeport, or Lanark today.        Begin Your Journey      Contact Form  Do not fill this form out if you're a solicitor.Name*   First    Last  Phone*Email*  Street Address PO Box or Apt # City* StateAlabamaAlaskaArizonaArkansasCaliforniaColoradoConnecticutDelawareFloridaGeorgiaGuamHawaiiIdahoIllinoisIndianaIowaKansasKentuckyLouisianaMaineMarylandMassachusettsMichiganMinnesotaMississippiMissouriMontanaNebraskaNevadaNew HampshireNew JerseyNew MexicoNew YorkNorth CarolinaNorth DakotaOhioOklahomaOregonPennsylvaniaRhode IslandSouth CarolinaSouth DakotaTennesseeTexasUtahVermontVirginiaWashingtonWest VirginiaWisconsinWyomingZip Code* What brought you to Anchor Wealth?  Financial Planning   Investments   Life Insurance   Long-Term Care Insurance My current investments(Select all that apply)  Roth IRA   401k/403b   Deferred Comp   College ESA/529   Annuities   Pension   Mutual Funds   Stocks/Bonds   CDs My current debts(Select all that apply)  Credit cards   School loans   Mortgage   Bank loans   Car loans   Personal loans   I'm debt free!!! How did you hear about us?  Radio Advertisement   Digital Advertisement   Internet search   Friend/family referral   Dave Ramsey Anything else you would like us to know or discuss?CAPTCHACommentsThis field is for validation purposes and should be left unchanged.                                             Learn       A 15-minute ph ...

# %% [markdown]
# ### Filter Words

# %%
from nltk.corpus import stopwords
import re

# nltk.download('stopwords')
print(stopwords.words('english'))
# remove wide Spaces
filter_words=[]
for x in file_contents:
    data = re.sub(r'\s+', ' ', x)
    words = data.split(' ')
    words=[x for x in words if len(x)>0]
    filter_words.append([w for w in words if w not in stopwords.words('English')])
print(filter_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [['Anchor', 'Wealth', 'Management', '-', 'Financial', 'Advisors', 'In', 'Rockford,', 'IL', 'Skip', 'content', 'HomeAboutServices', 'Services', 'Financial', 'Planning', 'Investment', 'Planning', 'Long-Term', 'Care', '&', 'Life', 'InsuranceCaptain’s', 'LogAnchor', 'NewsRefer', 'A', 'FriendLoginContact', 'Us', '815-201-5011', 'HomeAboutServices', 'Services', 'Financial', 'Planning', 'Investment', 'Planning', 'Long-Term', 'Care', '&', 'Life', 'InsuranceCaptain’s', 'LogAnchor', 'NewsRefer', 'A', 'FriendLoginContact', 'Us', 'CHART', 'YOUR', 'FINANCIAL', 'COURSE', 'TODAY', 'Begin', 'Your', 'Journey', 'Contact', 'Form', 'Do', 'fill', 'form', 'solicitor.Name*', 'First', 'Last', 'Phone*Email*', 'Street', 'Address', 'PO', 'Box', 'Apt', '#', 'City*', 'StateAlabamaAlaskaArizonaArkansasCaliforniaColoradoConnecticutDelawareFloridaGeorgiaGuamHawaiiIdahoIllinoisIndianaIowaKansasKentuckyLouisianaMaineMarylandMassachusettsMichiganMinnesotaMississippiMissouriMontanaNebraskaNevadaNew', 'HampshireNew', 'JerseyNew', 'MexicoNew', 'YorkNorth', 'CarolinaNorth', 'DakotaOhioOklahomaOregonPennsylvaniaRhode', 'IslandSouth', 'CarolinaSouth', 'DakotaTennesseeTexasUtahVermontVirginiaWashingtonWest', 'VirginiaWisconsinWyomingZip', 'Code*', 'What', 'brought', 'Anchor', 'Wealth?', 'Financial', 'Planning', 'Investments', 'Life', 'Insurance', 'Long-Term', 'Care', 'Insurance', 'My', 'current', 'investments(Select', 'apply)', 'Roth', 'IRA', '401k/403b', 'Deferred', 'Comp', 'College', 'ESA/529', 'Annuities', 'Pension', 'Mutual', 'Funds', 'Stocks/Bonds', 'CDs', 'My', 'current', 'debts(Select', 'apply)', 'Credit', 'cards', 'School', 'loans', 'Mortgage', 'Bank', 'loans', 'Car', 'loans', 'Personal', 'loans', "I'm", 'debt', 'free!!!', 'How', 'hear', 'us?', 'Radio', 'Advertisement', 'Digital', 'Advertisement', 'Internet', 'search', 'Friend/family', 'referral', 'Dave', 'Ramsey', 'Anything', 'else', 'would', 'like', 'us', 'know', 'discuss?CAPTCHAPhoneThis', 'field', 'validation', 'purposes', 'left', 'unchanged.', 'Check', 'The', 'Background', 'Of', 'This', 'Investment', 'Professional', 'On', 'FINRA’s', 'BrokerCheck', 'OUR', 'PROCESS', 'Learn', 'Teach', 'Begin', 'Stay', 'HOW', 'WE', 'WORK', 'As', 'long', 'journey,', 'begin', 'wealth', 'management', 'planning', 'end', 'mind.', 'By', 'understanding', 'want', 'journey', 'ends,', 'better', 'able', 'chart', 'course', 'financial', 'advisors.', 'And', 'never', 'predict', 'bumps', 'diversions,', 'better', 'prepare', 'them.', 'Get', 'contact', 'financial', 'advisor', 'Rockford,', 'Freeport,', 'Lanark', 'today.', 'Begin', 'Your', 'Journey', 'Contact', 'Form', 'Do', 'fill', 'form', 'solicitor.Name*', 'First', 'Last', 'Phone*Email*', 'Street', 'Address', 'PO', 'Box', 'Apt', '#', 'City*', 'StateAlabamaAlaskaArizonaArkansasCaliforniaColoradoConnecticutDelawareFloridaGeorgiaGuamHawaiiIdahoIllinoisIndianaIowaKansasKentuckyLouisianaMaineMarylandMassachusettsMichiganMinnesotaMississippiMissouriMontanaNebraskaNevadaNew', 'HampshireNew', 'JerseyNew', 'MexicoNew', 'YorkNorth', 'CarolinaNorth', 'DakotaOhioOklahomaOregonPennsylvaniaRhode', 'IslandSouth', 'CarolinaSouth', 'DakotaTennesseeTexasUtahVermontVirginiaWashingtonWest', 'VirginiaWisconsinWyomingZip', 'Code*', 'What', 'brought', 'Anchor', 'Wealth?', 'Financial', 'Planning', 'Investments', 'Life', 'Insurance', 'Long-Term', 'Care', 'Insurance', 'My', 'current', 'investments(Select', 'apply)', 'Roth', 'IRA', '401k/403b', 'Deferred', 'Comp', 'College', 'ESA/529', 'Annuities', 'Pension', 'Mutual', 'Funds', 'Stocks/Bonds', 'CDs', 'My', 'current', 'debts(Select', 'apply)', 'Credit', 'cards', 'School', 'loans', 'Mortgage', 'Bank', 'loans', 'Car', 'loans', 'Personal', 'loans', "I'm", 'debt', 'free!!!', 'How', 'hear', 'us?', 'Radio', 'Advertisement', 'Digital', 'Advertisement', 'Internet', 'search', 'Friend/family', 'referral', 'Dave', 'Ramsey', 'Anything', 'else', 'would', 'like', 'us', 'know', 'discuss?CAPTCHACommentsThis', 'field', 'validation', 'purposes', 'left', 'unchanged.', 'Learn', 'A', '15-mi ...

# %%
def directedGraph(arr):
    adj_list = dict()
    prev = arr[0]
    for x in arr[1:]:
        if(prev in adj_list):
            if(x not in adj_list[prev]):
                adj_list[prev].append(x)
        else:
            adj_list[prev] = [x]
        prev=x
    return adj_list

def store_graph(file_name:str,data:dict):
    file_name=file_name.split('/')[-1]
    
    # directory = os.path.dirname(file_name)
    # if not os.path.exists(directory):
    #     os.makedirs(directory)

    with open(f'../directedGraph/{file_name}', 'w') as file:
        for key, value in data.items():
            file.write(f"{key}:{','.join(value)}\n")

for index in range(len(filter_words)):
    store_graph(files[index],directedGraph(filter_words[index]))
